# %%
#import necessary libraries
import sys
sys.path.append("..")
from models.models import InnerProduct
import pandas as pd
import torch
import collections
import numpy as np
import torch.nn as nn
import os
import argparse
from data_processing.articles import Articles
from models.models import InnerProduct
import data_processing.dictionaries as dictionary
import sampling.sampler_util as sampler_util
import training.eval_util as eval_util
from pathlib import Path
from torch.utils.tensorboard import SummaryWriter
import json
from pandas import json_normalize

def expand_path(string):
    return Path(os.path.expandvars(string))
#get arguments for script and parse
parser = argparse.ArgumentParser(description='Train model on article data and test evaluation')
parser.add_argument('--model_path',
                    type=expand_path,
                    help="This is required to load model.")

parser.add_argument('--dict_dir',
                    type=expand_path,
                    help="This is required to load dictionaries")

parser.add_argument('--dataset_path',
                    type=expand_path,
                    required=True,
                    help='Path to data to be ranked.')

args = parser.parse_args()

dict_dir = Path(args.dict_dir)
final_word_ids,final_url_ids, final_publication_ids = dictionary.load_dictionaries(dict_dir)
print("Dictionaries loaded.")

data_path = Path(args.dataset_path)
dataset = Articles(data_path)
print("Data loaded.")

dataset.tokenize()
print("Data tokenized.")
word_counter = collections.Counter()
for example in dataset.examples:
    word_counter.update(example['text'])

unique_words = [word for word in word_counter.keys()]
len(set(unique_words))

abs_model_path = Path(args.model_path)
kwargs = dict(n_publications=len(final_publication_ids),
              n_articles=len(final_url_ids),
              n_attributes=len(final_word_ids),
              emb_size=100,
              sparse=False,
              use_article_emb=False,
              mode='mean')
model = InnerProduct(**kwargs)
model.load_state_dict(torch.load(abs_model_path))
print("Model Loaded.")

publication_emb = model.publication_embeddings.weight.data[0].cpu().numpy()
publication_bias = model.publication_bias.weight.data[0].cpu().numpy()
word_emb = model.attribute_emb_sum.weight.data.cpu().numpy()
word_bias = model.attribute_bias_sum.weight.data.cpu().numpy()

unique_words = list(set(unique_words))
word_emb_and_bias_dict = {}
for word in unique_words:
    if final_word_ids.get(word, 'None') != 'None':
        idx = final_word_ids.get(word, 'None')
        current_emb = list(word_emb[idx].astype(float))
        current_bias = list(word_bias[idx].astype(float))[0]
        current_short_dict = {'embedding':current_emb, 'bias':current_bias}
        word_emb_and_bias_dict[word] = current_short_dict

with open("word_to_emb+bias_dict.json", 'w') as file:
    json.dump(word_emb_and_bias_dict, file, separators=(',', ':'))
print("Model Embeddings and Bias Saved!")

pub_dict = {"embedding": list(publication_emb.astype(float)), "bias": list(publication_bias.astype(float))[0]}
with open("pub_emb+bias.json", 'w') as file:
    json.dump(pub_dict, file, separators=(',', ':'))
print("Publication Embeddings Saved!")

df = json_normalize(dataset)
df.drop(columns=['link', 'model_publication'], inplace=True)
df = df[df.text.apply(lambda x: len(x) > 400)]
df.to_json("select_demo_articles.json", orient='records')
print("Demo Articles Saved!")
# Out:
# Dictionaries loaded.
# Data loaded.
# Data tokenized.
# Model Loaded.
# Model Embeddings and Bias Saved!
# Publication Embeddings Saved!
# Demo Articles Saved!

# %%
list(publication_bias.astype(float))[0]
# Out:
# 0.9955700039863586

# %%
#import necessary libraries
import numpy as np
from scipy.sparse import csr_matrix
from pathlib import Path
import sys
sys.path.append("..")
from models.models import InnerProduct
import pandas as pd
import torch
import collections
import numpy as np
import torch.nn as nn
import os
import argparse
from data_processing.articles import Articles
from models.models import InnerProduct
import data_processing.dictionaries as dictionary
from pathlib import Path
import json
from pandas import json_normalize
from scipy import sparse
import boto3

dict_dir = Path("../../data/dictionaries")
final_word_ids,final_url_ids, final_publication_ids = dictionary.load_dictionaries(dict_dir)
print("Dictionaries loaded.")

data_path = Path('../../data/UI_feeds/scrape_data/browser-rss-articles-info.json')
dataset = Articles(data_path)
print("Data loaded.")

abs_model_path = Path("../../data/gridsearch_results/2020-05-25/optimizer_type=RMS_use_all_words=False_emb_size=100_learning_rate=0.0001_word_embedding_type=mean/model/mean-inner-product-model.pt")
kwargs = dict(n_publications=len(final_publication_ids),
              n_articles=len(final_url_ids),
              n_attributes=len(final_word_ids),
              emb_size=100,
              sparse=False,
              use_article_emb=False,
              mode='mean')
model = InnerProduct(**kwargs)
model.load_state_dict(torch.load(abs_model_path))
print("Model Loaded.")

dataset.tokenize()
proper_data = dataset.map_items(final_word_ids,
                    final_url_ids,
                    final_publication_ids,
                    filter=True,
                    min_length=400)

data_path = Path("/users/rohan/news-classification/Data/feed_ranks/data")
if not data_path.is_dir():
    data_path.mkdir()
mapped_data_path = data_path / "mapped-data"
if not mapped_data_path.is_dir():
    mapped_data_path.mkdir()
train_mapped_path = mapped_data_path / "mapped_dataset.json"
with open(train_mapped_path, "w") as file:
    json.dump(proper_data, file)
raw_data = Articles(train_mapped_path)
print("Final: ", len(raw_data))
print(f"Filtered, Mapped Data saved to {mapped_data_path} directory")
print("-------------------")

word_articles = csr_matrix((len(raw_data), len(final_word_ids)), dtype=np.float32).toarray()

for idx, item in enumerate(raw_data.examples):
    item['text'] = list(set(item['text']))
    for entry in item['text']:
        word_articles[idx][entry] = 1

publication_emb = model.publication_embeddings.weight.data[0].cpu().numpy()
publication_bias = model.publication_bias.weight.data[0].cpu().numpy()
word_emb = model.attribute_emb_sum.weight.data.cpu().numpy()
word_bias = model.attribute_bias_sum.weight.data.cpu().numpy()

np.save("word_articles.npy", word_articles)
print("Article-Word Matrix Saved")

np.save("word_emb.npy", word_emb)
print("Word Embeddings Saved")

np.save("word_bias.npy", word_bias)
print("Word Biases Saved")

with open("/users/rohan/news-classification/Data/feed_ranks/data/mapped-data/mapped_dataset.json",'r') as file:
    real_data = json.load(file)
    
with open('/users/rohan/news-classification/data/dictionaries/reversed_word_ids.json', "r") as file:
    id_to_word = json.load(file)


BUCKET = 'personal-bucket-news-ranking'
client = boto3.client('s3',
                      aws_access_key_id='xxxxxxxxxxxxxxx',
                      aws_secret_access_key='xxxxxxxxxxxx'
                      )

client.upload_file("word_articles.npz", BUCKET, "word_articles.npy")
client.upload_file("word_emb.npy", BUCKET, "word_emb.npy")
client.upload_file("word_bias.npy", BUCKET, "word_bias.npy")
client.upload_file("/users/rohan/news-classification/Data/feed_ranks/data/mapped-data/mapped_dataset.json", BUCKET, "mapped-data.json")
client.upload_file("/users/rohan/news-classification/data/dictionaries/reversed_word_ids.json", BUCKET, "id_to_word.json")
print("Data Uploaded Successfully!")
# Out:
# Dictionaries loaded.
# Data loaded.
# Model Loaded.
# Final:  8234
# Filtered, Mapped Data saved to \users\rohan\news-classification\Data\feed_ranks\data\mapped-data directory
# -------------------
# Article-Word Matrix Saved
# Word Embeddings Saved
# Word Biases Saved
# '\nBUCKET = \'personal-bucket-news-ranking\'\nclient = boto3.client(\'s3\',\n                      aws_access_key_id=\'AKIAJYHEV666HJ7A3QGQ\',\n                      aws_secret_access_key=\'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\'\n                      )\n\nclient.upload_file("word_articles.npy", BUCKET, "word_articles.npy")\nclient.upload_file("word_emb.npy", BUCKET, "word_emb.npy")\nclient.upload_file("word_bias.npy", BUCKET, "word_bias.npy")\nclient.upload_file("/users/rohan/news-classification/Data/feed_ranks/data/mapped-data/mapped_dataset.json", BUCKET, "mapped-data.json")\nclient.upload_file("/users/rohan/news-classification/data/dictionaries/reversed_word_ids.json", BUCKET, "id_to_word.json")\nprint("Data Uploaded Successfully!")\n'

# %%
import scipy

scipy.sparse.save_npz("csr_articles.npz", csr_matrix(word_articles))

# %%
article_embeddings = (csr_matrix(word_articles) * csr_matrix(word_emb)).toarray()

emb_times_publication = np.dot(article_embeddings, publication_emb.reshape(100,1))

article_bias = np.dot(word_articles, word_bias)

product_with_bias = emb_times_publication + article_bias

word_counts = word_articles.sum(axis=1).reshape(word_articles.shape[0], 1)

final_logits = np.divide(product_with_bias, word_counts) + float(publication_bias)

# %%
np.amax(final_logits)

# %%
import numpy as np
from scipy.sparse import csr_matrix

publication_emb = np.asarray([1.0440499, 1.0030843, 1.0340449, 0.992087, 1.0509816, 1.0315005, -1.0493797, -1.0198538, 0.9712321, -1.026394, 
            -0.9687971, 1.0592866, -1.0200703, -1.0423145, 0.9929519, 1.0220934, 1.021279, -1.0265925, 0.9601833, 0.9763889, 
            1.0109168, -0.9728226, 0.97199583, -1.0237931, -0.9996001, 0.9932069, 0.97966635, -0.98893607, -0.9876815, -0.98812914, 
            -0.9625895, 0.99879754, 0.9876508, -0.9581506, -0.95436096, -0.9601925, -1.0134513, -0.98763955, 0.98665, -1.0140482, 
            1.004904, 0.9894275, -1.0044671, -0.9839679, -0.97082543, -0.9798079, 0.9926766, -0.97317344, 0.9797, -0.97642475, 
            -0.99420726, -0.9972062, -1.0104703, 1.0575777, 0.9957696, -1.0413874, -1.0056863, -1.0151271, -0.99969465, 0.97463423, 
            -0.98398715, -1.0211866, -1.0128828, -1.0024365, -0.9800189, 1.0457181, 1.0155835, -1.036794, -1.013707, -1.0498024, 
            -1.0252678, -1.0388161, -0.97501564, 0.97687274, 0.97906756, 1.0536852, 1.0590494, -0.96917725, 1.0247189, -0.9818878, 
            -1.0417286, -1.0204054, -1.0285249, -1.0329671, 0.9705739, 0.96375024, 0.9891868, 0.9892464, 1.039075, 1.0042666,
            0.9786834, 1.0199072, 0.98080486, 0.9698635, -0.99322844, -0.95841753, -0.99150276, 0.97394156, 0.9976019, -1.0375009], dtype=np.float32)

publication_bias = 0.99557
word_articles = np.load('word_articles.npy')
word_emb = np.load('word_emb.npy')
word_bias = np.load('word_bias.npy')

print("Data Loaded Successfully!")
# Out:
# Data Loaded Successfully!

# %%
import time
time1 = time.time()
article_embeddings = np.dot(word_articles, word_emb)

emb_times_publication = np.dot(article_embeddings, publication_emb.reshape(100,1))

article_bias = np.dot(word_articles, word_bias)

product_with_bias = emb_times_publication + article_bias

word_counts = word_articles.sum(axis=1).reshape(word_articles.shape[0], 1)

final_logits = np.divide(product_with_bias, word_counts) + float(publication_bias)

word_logits = np.dot(word_emb, publication_emb.reshape(100,1)) + word_bias
broadcasted_words_per_article =word_articles * word_logits.T
sorted_word_indices = broadcasted_words_per_article.argsort(axis=1)

time2 = time.time()

print(time2-time1)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-5-ace43847e953> in <module>
#      15 word_logits = np.dot(word_emb, publication_emb.reshape(100,1)) + word_bias
#      16 broadcasted_words_per_article =word_articles * word_logits.T
# ---> 17 sorted_word_indices = broadcasted_words_per_article.argsort(axis=1)
#      18
#      19 time2 = time.time()
#
# MemoryError: Unable to allocate 27.5 GiB for an array with shape (8234, 448718) and data type int64

# %%
broadcasted_words_per_article.shape
# Out:
# (8234, 448718)

# %%
len(final_word_ids)
# Out:
# 448718

# %%
reversed_word_ids = {v: k for k, v in final_word_ids.items()}

# %%
with open('/users/rohan/news-classification/data/dictionaries/reversed_word_ids.json', "w") as file:
    json.dump(reversed_word_ids, file)

# %%
import numpy as np
from scipy.sparse import csr_matrix
import time
import json
import scipy

publication_emb = np.asarray([1.0440499, 1.0030843, 1.0340449, 0.992087, 1.0509816, 1.0315005, -1.0493797, -1.0198538, 0.9712321, -1.026394, 
            -0.9687971, 1.0592866, -1.0200703, -1.0423145, 0.9929519, 1.0220934, 1.021279, -1.0265925, 0.9601833, 0.9763889, 
            1.0109168, -0.9728226, 0.97199583, -1.0237931, -0.9996001, 0.9932069, 0.97966635, -0.98893607, -0.9876815, -0.98812914, 
            -0.9625895, 0.99879754, 0.9876508, -0.9581506, -0.95436096, -0.9601925, -1.0134513, -0.98763955, 0.98665, -1.0140482, 
            1.004904, 0.9894275, -1.0044671, -0.9839679, -0.97082543, -0.9798079, 0.9926766, -0.97317344, 0.9797, -0.97642475, 
            -0.99420726, -0.9972062, -1.0104703, 1.0575777, 0.9957696, -1.0413874, -1.0056863, -1.0151271, -0.99969465, 0.97463423, 
            -0.98398715, -1.0211866, -1.0128828, -1.0024365, -0.9800189, 1.0457181, 1.0155835, -1.036794, -1.013707, -1.0498024, 
            -1.0252678, -1.0388161, -0.97501564, 0.97687274, 0.97906756, 1.0536852, 1.0590494, -0.96917725, 1.0247189, -0.9818878, 
            -1.0417286, -1.0204054, -1.0285249, -1.0329671, 0.9705739, 0.96375024, 0.9891868, 0.9892464, 1.039075, 1.0042666,
            0.9786834, 1.0199072, 0.98080486, 0.9698635, -0.99322844, -0.95841753, -0.99150276, 0.97394156, 0.9976019, -1.0375009], dtype=np.float32)

publication_bias = 0.99557
word_articles = scipy.sparse.load_npz('/users/rohan/news-classification/Data/demo-data/csr_articles.npz')
word_emb = np.load('/users/rohan/news-classification/Data/demo-data/word_emb.npy')
word_bias = np.load('/users/rohan/news-classification/Data/demo-data/word_bias.npy')

with open("/users/rohan/news-classification/Data/feed_ranks/data/mapped-data/mapped_dataset.json",'r') as file:
    real_data = json.load(file)
    
with open('/users/rohan/news-classification/data/dictionaries/reversed_word_ids.json', "r") as file:
    id_to_word = json.load(file)
print("Data Loaded Successfully!")

time1 = time.time()
article_embeddings = word_articles.dot(word_emb)

emb_times_publication = np.dot(article_embeddings, publication_emb.reshape(100,1))

article_bias = word_articles.dot(word_bias)

product_with_bias = emb_times_publication + article_bias

word_counts = word_articles.sum(axis=1).reshape(word_articles.shape[0], 1)

final_logits = np.divide(product_with_bias, word_counts) + float(publication_bias)

indices = final_logits.argsort(axis=0)[-75:].reshape(75)

word_logits = np.dot(word_emb, publication_emb.reshape(100,1)) + word_bias
# Out:
# Data Loaded Successfully!

# %%
word_articles[indices.tolist()[0]]
# Out:
# <75x448718 sparse matrix of type '<class 'numpy.float32'>'
# 	with 45607 stored elements in Compressed Sparse Row format>

# %%
import requests

URL = "https://icf3cc3rt8.execute-api.us-east-2.amazonaws.com/default/rank_news_demo"
PARAMS = '{"body": {"change": True, "a": 0.2, "b": 5, "c": 100, "d": -24, "e": -37}}'
r = requests.post(url = URL, params = PARAMS) 
data = r.json()

# %%
data
# Out:
# {'message': 'Internal Server Error'}

# %%
import subprocess
CurlUrl = 'curl -X GET https://icf3cc3rt8.execute-api.us-east-2.amazonaws.com/default/rank_news_demo -d \"{"change": 1, "a": 0.2, "b": 5, "c": 100, "d": -24, "e": -37}\"'
status, output = subprocess.getstatusoutput(CurlUrl)

# %%
output
# Out:
# '  % Total    % Received % Xferd  Average Speed   Time    Time     Time  Current\n                                 Dload  Upload   Total   Spent    Left  Speed\n\n  0     0    0     0    0     0      0      0 --:--:-- --:--:-- --:--:--     0\n100    84  100    35  100    49     91    128 --:--:-- --:--:-- --:--:--   221\n{"message":"Internal Server Error"}'

# %%
import numpy as np
from scipy.sparse import csr_matrix
import time
import json
import scipy

publication_emb = np.asarray([1.0440499, 1.0030843, 1.0340449, 0.992087, 1.0509816, 1.0315005, -1.0493797, -1.0198538, 0.9712321, -1.026394, 
            -0.9687971, 1.0592866, -1.0200703, -1.0423145, 0.9929519, 1.0220934, 1.021279, -1.0265925, 0.9601833, 0.9763889, 
            1.0109168, -0.9728226, 0.97199583, -1.0237931, -0.9996001, 0.9932069, 0.97966635, -0.98893607, -0.9876815, -0.98812914, 
            -0.9625895, 0.99879754, 0.9876508, -0.9581506, -0.95436096, -0.9601925, -1.0134513, -0.98763955, 0.98665, -1.0140482, 
            1.004904, 0.9894275, -1.0044671, -0.9839679, -0.97082543, -0.9798079, 0.9926766, -0.97317344, 0.9797, -0.97642475, 
            -0.99420726, -0.9972062, -1.0104703, 1.0575777, 0.9957696, -1.0413874, -1.0056863, -1.0151271, -0.99969465, 0.97463423, 
            -0.98398715, -1.0211866, -1.0128828, -1.0024365, -0.9800189, 1.0457181, 1.0155835, -1.036794, -1.013707, -1.0498024, 
            -1.0252678, -1.0388161, -0.97501564, 0.97687274, 0.97906756, 1.0536852, 1.0590494, -0.96917725, 1.0247189, -0.9818878, 
            -1.0417286, -1.0204054, -1.0285249, -1.0329671, 0.9705739, 0.96375024, 0.9891868, 0.9892464, 1.039075, 1.0042666,
            0.9786834, 1.0199072, 0.98080486, 0.9698635, -0.99322844, -0.95841753, -0.99150276, 0.97394156, 0.9976019, -1.0375009], dtype=np.float32)

publication_bias = 0.99557
word_articles = scipy.sparse.load_npz('/users/rohan/news-classification/Data/demo-data/csr_articles.npz')
word_emb = np.load('/users/rohan/news-classification/Data/demo-data/word_emb.npy')
word_bias = np.load('/users/rohan/news-classification/Data/demo-data/word_bias.npy')

with open("/users/rohan/news-classification/Data/feed_ranks/data/mapped-data/mapped_dataset.json",'r') as file:
    real_data = json.load(file)
    
with open('/users/rohan/news-classification/data/dictionaries/reversed_word_ids.json', "r") as file:
    id_to_word = json.load(file)
print("Data Loaded Successfully!")

time1 = time.time()
article_embeddings = word_articles.dot(word_emb)

emb_times_publication = np.dot(article_embeddings, publication_emb.reshape(100,1))

article_bias = word_articles.dot(word_bias)

product_with_bias = emb_times_publication + article_bias

word_counts = word_articles.sum(axis=1).reshape(word_articles.shape[0], 1)

final_logits = np.divide(product_with_bias, word_counts) + float(publication_bias)

indices = final_logits.argsort(axis=0)[-75:].reshape(75)

word_logits = np.dot(word_emb, publication_emb.reshape(100,1)) + word_bias

top_articles = word_articles[indices.tolist()[0]]

broadcasted_words_per_article = top_articles.toarray() * word_logits.T

sorted_word_indices = broadcasted_words_per_article.argsort(axis=1)

return_articles = []

i=0
for idx in indices.tolist()[0]:
    print(idx)
    current_article = real_data[int(idx)]
    current_article['logit'] = float(final_logits[int(idx)])
    current_sorted_words = sorted_word_indices[i]
    top_words = []
    least_words = []
    for top_word in current_sorted_words[-10:]:
        word = id_to_word[str(top_word)]
        top_words.append(word)
    for least_word in current_sorted_words[:10]:
        word = id_to_word[str(least_word)]
        least_words.append(word)
    current_article['top_words'] = top_words
    current_article['least_words'] = least_words
    return_articles.append(current_article)
    i+=1
    
time2 = time.time()

print(time2-time1)

# %%
ordered_return_articles = return_articles[::-1]
grand_html = []
for idx, article in enumerate(ordered_return_articles):
    grand_html.append("<tr>")
    grand_html.append(f"<td>{idx+1}</td>")
    grand_html.append(f"<td class=\"title mdl-data-table__cell--non-numeric\"><a href=\"{article['link']}\">{article['title']}</a></td>")
    grand_html.append(f"<td class=\"logit\">{article['logit']}</td>")
    top_word_list = ""
    for item in article['top_words']:
        if len(item) > 2:
            top_word_list += item
            top_word_list += ", "
    least_word_list = ""
    for item in article['least_words']:
        if len(item) > 2:
            least_word_list += item
            least_word_list += ", "
    grand_html.append(f"<td class=\"top_words mdl-data-table__cell--non-numeric\">{top_word_list[:-2]}</td>")
    grand_html.append(f"<td class=\"least_words mdl-data-table__cell--non-numeric\">{least_word_list[:-2]}</td>")
    grand_html.append("</tr>")
print("\n".join(grand_html))
# Out:
# <tr>
# <td>1</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="http://www.colinmcginn.net/mind-dependence/">Mind-Dependence</a></td>
# <td class="logit">7.9061784744262695</td>
# <td class="top_words mdl-data-table__cell--non-numeric">finite, thus, neurons, notion, hence, indeed, attractive, suppose, moreover</td>
# <td class="least_words mdl-data-table__cell--non-numeric">isn, says, stemming, including, also, appearance, arguing</td>
# </tr>
# <tr>
# <td>2</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://www.simonsfoundation.org/2020/05/06/finding-prime-locations-the-continuing-challenge-to-prove-the-riemann-hypothesis/">Finding Prime Locations: The Continuing Challenge to Prove the Riemann Hypothesis</a></td>
# <td class="logit">7.137406826019287</td>
# <td class="top_words mdl-data-table__cell--non-numeric">hypothesis, consisting, conjecture, behavior, graph, whereas, wikimedia, domain, credit</td>
# <td class="least_words mdl-data-table__cell--non-numeric">above, key, gives, series, makes, suggests, than, friedrich, 1700s</td>
# </tr>
# <tr>
# <td>3</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="http://thedabbler.co.uk/2017/01/review-manly-manners-for-the-impeccable-gent-by-guy-egmont/">Review: Manly Manners for the Impeccable Gent – by Guy Egmont</a></td>
# <td class="logit">6.296250343322754</td>
# <td class="top_words mdl-data-table__cell--non-numeric">silent, club, money, arranged, wives, etc, reader, talk, harvard, secretaries</td>
# <td class="least_words mdl-data-table__cell--non-numeric">season, exec, workplace, says, deal, titled, emboldened, also, women</td>
# </tr>
# <tr>
# <td>4</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="http://justice-everywhere.org/general/should-economics-be-pluralist/">Should Economics be Pluralist?</a></td>
# <td class="logit">6.169751167297363</td>
# <td class="top_words mdl-data-table__cell--non-numeric">analogy, economics, behavior, statistical, suppose, behavioral, 2008, pdf</td>
# <td class="least_words mdl-data-table__cell--non-numeric">while, according, argued, delves, finding, currently, also, sweden, actually</td>
# </tr>
# <tr>
# <td>5</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="http://cognitionandculture.net/blogs/helena-miton/ubiquitous-yet-nowhere-to-be-found-on-the-invisible-hands-success/">Ubiquitous yet nowhere to be found: on the Invisible Hand’s success</a></td>
# <td class="logit">6.115911960601807</td>
# <td class="top_words mdl-data-table__cell--non-numeric">behavioral, 2011, credit, 2009</td>
# <td class="least_words mdl-data-table__cell--non-numeric">explaining, shows, essentially, while, watch, journal, includes, offering, inquiry, finding</td>
# </tr>
# <tr>
# <td>6</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://nplusonemag.com/issue-35/fiction-drama/the-creature/">The Creature</a></td>
# <td class="logit">5.8149309158325195</td>
# <td class="top_words mdl-data-table__cell--non-numeric">ever, account, whenever, the, knew, friend, names, handsome, inbox, drive</td>
# <td class="least_words mdl-data-table__cell--non-numeric">wrote, winds, bit, white, really, after, was, stop</td>
# </tr>
# <tr>
# <td>7</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://tante.cc/2018/11/28/experte-zum-thema-blockchain-beim-ausschuss-digitale-agenda-des-bundestages/">Experte zum Thema Blockchain beim Ausschuss Digitale Agenda des Bundestages</a></td>
# <td class="logit">5.654151916503906</td>
# <td class="top_words mdl-data-table__cell--non-numeric">governments, the, quasi, den, und, von</td>
# <td class="least_words mdl-data-table__cell--non-numeric">brexit, digital, deutschland, today, around, was, saying, ganz, blockchain, für</td>
# </tr>
# <tr>
# <td>8</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="http://feedproxy.google.com/~r/nybooks/~3/Q76K1CCLbwA/">Fun for One</a></td>
# <td class="logit">5.581697463989258</td>
# <td class="top_words mdl-data-table__cell--non-numeric">the, southwest, sound, table, microphone, arms, brown, desk, sitting, onto</td>
# <td class="least_words mdl-data-table__cell--non-numeric">stone, while, watch, sonia, said, crossing, broadway, lead</td>
# </tr>
# <tr>
# <td>9</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://tante.cc/2020/04/21/bluetooth-abstandsmessung-und-algorithmen/">Bluetooth Abstandsmessung und Algorithmen</a></td>
# <td class="logit">5.57907247543335</td>
# <td class="top_words mdl-data-table__cell--non-numeric">centimeter, quasi, mich, den, liked, box, und, system, patreon, von</td>
# <td class="least_words mdl-data-table__cell--non-numeric">2020, apps, also, proxies, was, ganz, via, für</td>
# </tr>
# <tr>
# <td>10</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://www.bayesianspectacles.org/omit-needless-words-an-unapproachable-example-of-conciseness-related-by-the-traveling-chinese-story-teller-kai-lung/">Omit Needless Words: An Unapproachable Example of Conciseness Related by the Traveling Chinese Story-teller Kai Lung</a></td>
# <td class="logit">5.50782585144043</td>
# <td class="top_words mdl-data-table__cell--non-numeric">the, incapable, 1935, jan, manner, 2000, indeed, mentioned, ten</td>
# <td class="least_words mdl-data-table__cell--non-numeric">read, added, 2020, said, means, sings, pearson, prevent</td>
# </tr>
# <tr>
# <td>11</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://nplusonemag.com/online-only/online-only/pretty-girl-with-bad-hair/">Pretty Girl with Bad Hair</a></td>
# <td class="logit">5.4934492111206055</td>
# <td class="top_words mdl-data-table__cell--non-numeric">eighteen, jeans, pages, translated, ten, fifty, eighteenth, forty, twenty</td>
# <td class="least_words mdl-data-table__cell--non-numeric">read, 2014, pretty, watch, journal, saturday, ahead, popular, above</td>
# </tr>
# <tr>
# <td>12</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://blog.jessriedel.com/2019/09/23/the-interpretation-of-free-energy-as-bit-erasure-capacity/">The interpretation of free energy as bit-erasure capacity</a></td>
# <td class="logit">5.482933044433594</td>
# <td class="top_words mdl-data-table__cell--non-numeric">system, summary, hence, indeed, obvious, henceforth, 1st, blog</td>
# <td class="least_words mdl-data-table__cell--non-numeric">isn, specifically, doesn, initially, above, bit</td>
# </tr>
# <tr>
# <td>13</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://inference-review.com/index.php/article/the-good-soldier">The Good Soldier</a></td>
# <td class="logit">5.382519245147705</td>
# <td class="top_words mdl-data-table__cell--non-numeric">oil, satisfaction, behavior, suppose, emergence, tea, pages, hundred</td>
# <td class="least_words mdl-data-table__cell--non-numeric">read, twitter, rolling, changing, stone, added, wrote, code, drama</td>
# </tr>
# <tr>
# <td>14</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="http://www.oneill.io/2020/04/29/why-do-dogs-howl-at-the-moon/">Why do dogs howl at the moon?</a></td>
# <td class="logit">5.312851905822754</td>
# <td class="top_words mdl-data-table__cell--non-numeric">please, hung, empty, days, the, liked, television, reader, drive, wondered</td>
# <td class="least_words mdl-data-table__cell--non-numeric">read, actively, key, also, letting, definitely, found, her, was</td>
# </tr>
# <tr>
# <td>15</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="http://www.colinmcginn.net/phenomenological-knowledge/">Phenomenological Knowledge</a></td>
# <td class="logit">5.302178859710693</td>
# <td class="top_words mdl-data-table__cell--non-numeric">insist, hence, indeed, etc, exceed, obvious, faculty, suppose, whereas, occupy</td>
# <td class="least_words mdl-data-table__cell--non-numeric">pretty, isn, doesn, argued, alleged, deal, totally, twist</td>
# </tr>
# <tr>
# <td>16</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="http://copper-nickel.org/the-missing-are-considered-dead/">The Missing Are Considered Dead</a></td>
# <td class="logit">5.299867153167725</td>
# <td class="top_words mdl-data-table__cell--non-numeric">smile, troubled, talk, neighborhood, neighbor, tea, wondered, occupy, thirty</td>
# <td class="least_words mdl-data-table__cell--non-numeric">related, hide, isn, serve, while, watch, moments, hopeful, barrier</td>
# </tr>
# <tr>
# <td>17</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://blog.jessriedel.com/2020/05/11/a-checkable-lindbladian-condition/">A checkable Lindbladian condition</a></td>
# <td class="logit">5.253383159637451</td>
# <td class="top_words mdl-data-table__cell--non-numeric">etc, generated, onto, furthermore, domain, blog, pdf</td>
# <td class="least_words mdl-data-table__cell--non-numeric">clarity, statement, barrier, above, said, aren, map, totally</td>
# </tr>
# <tr>
# <td>18</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="http://feedproxy.google.com/~r/oupblog/~3/OvGDLbdi2s0/">The words of the day</a></td>
# <td class="logit">5.237738609313965</td>
# <td class="top_words mdl-data-table__cell--non-numeric">fourteenth, sixteenth, meetings, indeed, operative, 2008, image, pages, credit, blog</td>
# <td class="least_words mdl-data-table__cell--non-numeric">related, snap, statement, while, due, above, favorite, virus</td>
# </tr>
# <tr>
# <td>19</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://blog.andymatuschak.org/post/7565332844">Musical tone and perceived dissonance</a></td>
# <td class="logit">5.190851211547852</td>
# <td class="top_words mdl-data-table__cell--non-numeric">consonant, harmonic, hence, thousand, cell, hair, moreover</td>
# <td class="least_words mdl-data-table__cell--non-numeric">researchers, while, bunch, includes, rendition, basically, also, means</td>
# </tr>
# <tr>
# <td>20</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://www.nationalaffairs.com//blog/detail/findings-a-daily-roundup/capitalism-and-its-discontents">Capitalism and its Discontents</a></td>
# <td class="logit">5.154965400695801</td>
# <td class="top_words mdl-data-table__cell--non-numeric">moreover, pages, translated, thirty, 2009, 2007, nineteenth, twentieth</td>
# <td class="least_words mdl-data-table__cell--non-numeric">explaining, related, jennifer, ruth, earnings, journal, reported, focusing, particularly, families</td>
# </tr>
# <tr>
# <td>21</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://medium.com/@Chris_arnade/d-in-the-mcdonalds-a8e11318ec32?source=rss-9e28ee9292dc------2">D in the McDonald’s</a></td>
# <td class="logit">5.145820617675781</td>
# <td class="top_words mdl-data-table__cell--non-numeric">anymore, obvious, talk, parking, drug, mentioned, drive, thirty, twenty</td>
# <td class="least_words mdl-data-table__cell--non-numeric">read, pop, doesn, dedicated, 2013, genius, shocked, says, particularly</td>
# </tr>
# <tr>
# <td>22</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://inference-review.com/index.php/article/the-directors-cut">The Director’s Cut</a></td>
# <td class="logit">5.141969203948975</td>
# <td class="top_words mdl-data-table__cell--non-numeric">domain, von, hundred, eighteenth, forty, twenty</td>
# <td class="least_words mdl-data-table__cell--non-numeric">explaining, read, added, shows, wrote, serve, essentially, argued, follows</td>
# </tr>
# <tr>
# <td>23</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://blog.jessriedel.com/2019/08/23/on-computational-aestivation/">On computational aestivation</a></td>
# <td class="logit">5.131683349609375</td>
# <td class="top_words mdl-data-table__cell--non-numeric">computer, hypothesis, paradox, generated, incentives</td>
# <td class="least_words mdl-data-table__cell--non-numeric">read, shows, previously, while, stars, doesn, argued, ahead, jess</td>
# </tr>
# <tr>
# <td>24</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://www.waggish.org/2019/the-100-most-important-words-to-i-a-richards/">The 100 Most Important Words (to I. A. Richards)</a></td>
# <td class="logit">5.111241817474365</td>
# <td class="top_words mdl-data-table__cell--non-numeric">functioning, ing, notion, page, summary, reader, operative, hundred</td>
# <td class="least_words mdl-data-table__cell--non-numeric">read, twitter, adding, unnamed, facebook, health, worthy, held</td>
# </tr>
# <tr>
# <td>25</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://nplusonemag.com/online-only/online-only/misery/">Misery</a></td>
# <td class="logit">5.103696823120117</td>
# <td class="top_words mdl-data-table__cell--non-numeric">cell, tea, hair, afternoon, eighteen, wondered, translated, thirty, twenty</td>
# <td class="least_words mdl-data-table__cell--non-numeric">pretty, added, serve, while, moments, hopeful, saturday, fuel, holiday</td>
# </tr>
# <tr>
# <td>26</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://www.waggish.org/2019/robert-musil-in-martha-musils-coat/">Robert Musil in Martha Musil’s Coat</a></td>
# <td class="logit">5.094523906707764</td>
# <td class="top_words mdl-data-table__cell--non-numeric">kill, indeed, etc, statistical, hair, translated</td>
# <td class="least_words mdl-data-table__cell--non-numeric">while, watch, according, follows, said, edited, deserves</td>
# </tr>
# <tr>
# <td>27</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="http://cultureandcommunication.org/galloway/a-list-of-qualities">A List of Qualities</a></td>
# <td class="logit">5.083495616912842</td>
# <td class="top_words mdl-data-table__cell--non-numeric">languages, editors, indeed, whereas, 2008, web</td>
# <td class="least_words mdl-data-table__cell--non-numeric">digital, code, essentially, statement, argued, hardware, hasn, typically, appeals</td>
# </tr>
# <tr>
# <td>28</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://www.noahbrier.com/archives/2018/10/pareto-principle-aka-80-20-rule/">Pareto Principle (aka 80/20 Rule) [Framework of the Day]</a></td>
# <td class="logit">5.061043739318848</td>
# <td class="top_words mdl-data-table__cell--non-numeric">pages, dec, web, 2009, pdf, 2007, caption</td>
# <td class="least_words mdl-data-table__cell--non-numeric">2017, chart, https, wrote, percent, journal, follows, popular, explains</td>
# </tr>
# <tr>
# <td>29</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://jasoncollins.blog/2019/08/05/david-leiser-and-yhonatan-shemeshs-how-we-misunderstand-economics-and-why-it-matters-the-psychology-of-bias-distortion-and-conspiracy/">David Leiser and Yhonatan Shemesh’s How We Misunderstand Economics and Why it Matters: The Psychology of Bias, Distortion and Conspiracy</a></td>
# <td class="logit">5.0573906898498535</td>
# <td class="top_words mdl-data-table__cell--non-numeric">judgments, indeed, exceed, explanations, economics, israel, whereas, occasional, domain, 2006</td>
# <td class="least_words mdl-data-table__cell--non-numeric">related, confirmed, respondents, broader, items, offering, climate</td>
# </tr>
# <tr>
# <td>30</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://inference-review.com/index.php/article/trading-volatility">Trading Volatility</a></td>
# <td class="logit">5.056610584259033</td>
# <td class="top_words mdl-data-table__cell--non-numeric">indeed, obvious, analogy, behavior, assumed, suppose, whereas, ten</td>
# <td class="least_words mdl-data-table__cell--non-numeric">shows, percent, previously, essentially, while, according, argued, follows, investments</td>
# </tr>
# <tr>
# <td>31</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="http://feedproxy.google.com/~r/bodyliterature/QVDj/~3/VjIVrzyrK0g/">Bijan Najdi</a></td>
# <td class="logit">5.047688007354736</td>
# <td class="top_words mdl-data-table__cell--non-numeric">amongst, arms, translations, caspian, sitting, revolution, onto, gray, hair</td>
# <td class="least_words mdl-data-table__cell--non-numeric">read, watch, doesn, journal, saturday, including, carrying, currently, seeing</td>
# </tr>
# <tr>
# <td>32</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://inference-review.com/index.php/article/misused-terms-in-linguistics">Misused Terms in Linguistics</a></td>
# <td class="logit">5.042849540710449</td>
# <td class="top_words mdl-data-table__cell--non-numeric">behavioral, domain, neighboring, stimulus, ten, 2009, twenty</td>
# <td class="least_words mdl-data-table__cell--non-numeric">read, clarity, highlight, code, essentially, while, specifically, according, dedicated, argued</td>
# </tr>
# <tr>
# <td>33</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://nplusonemag.com/issue-34/fiction-drama/jackpot/">Jackpot</a></td>
# <td class="logit">5.023077487945557</td>
# <td class="top_words mdl-data-table__cell--non-numeric">seemed, hadn, money, casino, anymore, clapped, arab, talk, telephone</td>
# <td class="least_words mdl-data-table__cell--non-numeric">wrote, pilot, said, weren, during, told, women</td>
# </tr>
# <tr>
# <td>34</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://davidsimon.com/nightcops/">Nightcops</a></td>
# <td class="logit">5.016082763671875</td>
# <td class="top_words mdl-data-table__cell--non-numeric">afternoon, pages, credit, twelve, ten, fifteen, fifty, thirty, twenty</td>
# <td class="least_words mdl-data-table__cell--non-numeric">monday, digital, wrote, while, sunday, watch, tweeting, denied, existential, inappropriate</td>
# </tr>
# <tr>
# <td>35</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="http://feedproxy.google.com/~r/craigmod/~3/2YRm7Kfddlw/">[ridgeline] A Review of Beds — Part 1</a></td>
# <td class="logit">5.012973308563232</td>
# <td class="top_words mdl-data-table__cell--non-numeric">desk, box, notion, anymore, lobby, males, kilometers, hundred</td>
# <td class="least_words mdl-data-table__cell--non-numeric">rating, reminder, wrote, snap, serve, code, sunday, canada</td>
# </tr>
# <tr>
# <td>36</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://inference-review.com/index.php/article/the-miracle-of-general-equilibrium">The Miracle of General Equilibrium</a></td>
# <td class="logit">5.004232406616211</td>
# <td class="top_words mdl-data-table__cell--non-numeric">economics, emergence, 2009, cent, 2006, twentieth</td>
# <td class="least_words mdl-data-table__cell--non-numeric">donald, 2016, changing, 2015, added, serve, statement, argued, extremely</td>
# </tr>
# <tr>
# <td>37</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="http://paulkingsnorth.net/2018/08/01/the-circling/">The Circling</a></td>
# <td class="logit">4.981334686279297</td>
# <td class="top_words mdl-data-table__cell--non-numeric">cloudless, indeed, shit, suburb, explanations, crap, tea, pages, fifteen</td>
# <td class="least_words mdl-data-table__cell--non-numeric">isn, 2018, essentially, above, says, said, deal, travel</td>
# </tr>
# <tr>
# <td>38</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://www.philosophyofmoney.net/cyclical-sovereignty/">Cyclical sovereignty</a></td>
# <td class="logit">4.966983795166016</td>
# <td class="top_words mdl-data-table__cell--non-numeric">marginal, failure, bundesbank, obvious, ecb, conferences, fiscal, balance, stimulus, ten</td>
# <td class="least_words mdl-data-table__cell--non-numeric">verse, specifically, existential, due, proposal, historic, proves, during</td>
# </tr>
# <tr>
# <td>39</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://mavengame.com/2020/02/one-about-words/">one about words</a></td>
# <td class="logit">4.962460994720459</td>
# <td class="top_words mdl-data-table__cell--non-numeric">books, obscure, catfish, page, reader, balance, avenue, ten, twenty</td>
# <td class="least_words mdl-data-table__cell--non-numeric">read, netflix, isn, watch, says, deal, week</td>
# </tr>
# <tr>
# <td>40</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="http://cultureandcommunication.org/galloway/uncomputer">Uncomputer</a></td>
# <td class="logit">4.9133477210998535</td>
# <td class="top_words mdl-data-table__cell--non-numeric">realm, computation, thus, computer, biological, rational, paradox, system, indeed, twentieth</td>
# <td class="least_words mdl-data-table__cell--non-numeric">digital, wrote, essentially, according, meanwhile, particularly, key, themes, series, also</td>
# </tr>
# <tr>
# <td>41</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="http://www.colinmcginn.net/is-biology-a-normative-science/">Is Biology a Normative Science?</a></td>
# <td class="logit">4.885959625244141</td>
# <td class="top_words mdl-data-table__cell--non-numeric">system, manner, judgments, naïve, hence, indeed, etc, talk, suppose</td>
# <td class="least_words mdl-data-table__cell--non-numeric">healthier, isn, while, according, wellbeing, aimed, explains, focusing, particularly</td>
# </tr>
# <tr>
# <td>42</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://inference-review.com/index.php/article/the-social-set">The Social Set</a></td>
# <td class="logit">4.861191749572754</td>
# <td class="top_words mdl-data-table__cell--non-numeric">occasional, evidently, image, pages, von, hundred, fifty, forty, twenty, twentieth</td>
# <td class="least_words mdl-data-table__cell--non-numeric">twitter, added, museum, while, survivors, denied, argued, follows, remarks, diversity</td>
# </tr>
# <tr>
# <td>43</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://hedgehogreview.com/blog/thr/posts/against-projection-for-promise">Against Projection; For Promise</a></td>
# <td class="logit">4.85318660736084</td>
# <td class="top_words mdl-data-table__cell--non-numeric">indeed, reader, talk, articles, neighborhood, blog, ten, hundred, fifty, forty</td>
# <td class="least_words mdl-data-table__cell--non-numeric">twitter, season, digital, wrote, guide, says, swift</td>
# </tr>
# <tr>
# <td>44</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://evonomics.com/capitalisms-alone/">Capitalism(s), Alone</a></td>
# <td class="logit">4.852306365966797</td>
# <td class="top_words mdl-data-table__cell--non-numeric">economics, indispensable, whereas, web, thirty, 2010, copyright, nineteenth, twenty, twentieth</td>
# <td class="least_words mdl-data-table__cell--non-numeric">2014, percent, while, earnings, argued, 2013, typically, broadly, key, trend</td>
# </tr>
# <tr>
# <td>45</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="http://feedproxy.google.com/~r/craigmod/~3/YNfKJT4XvEk/">[essays] Notes on the Other</a></td>
# <td class="logit">4.833243370056152</td>
# <td class="top_words mdl-data-table__cell--non-numeric">onto, shirt, eighty, tea, hair, fourteen, nineteen, fifty, sixty, twenty</td>
# <td class="least_words mdl-data-table__cell--non-numeric">marvel, specifically, moments, due, performances, normalize, indigenous, women</td>
# </tr>
# <tr>
# <td>46</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://philosophynow.org/issues/137/Against_Neural_Philosophy_Of_Mind">Against Neural Philosophy Of Mind</a></td>
# <td class="logit">4.832546710968018</td>
# <td class="top_words mdl-data-table__cell--non-numeric">view, system, indeed, obvious, analogy, articles, assumed, emergence, nervous</td>
# <td class="least_words mdl-data-table__cell--non-numeric">read, related, prof, 2020, while, longstanding, according, argued, follows</td>
# </tr>
# <tr>
# <td>47</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="http://feedproxy.google.com/~r/flavorwire-rss/~3/zavZ69VA5XY/book-excerpt-james-thurbers-collected-fables-19625842">Book Excerpt: James Thurber's 'Collected Fables'</a></td>
# <td class="logit">4.814444541931152</td>
# <td class="top_words mdl-data-table__cell--non-numeric">reprinted, friend, thus, kill, articles, inc, preface, ten, copyright, twenty</td>
# <td class="least_words mdl-data-table__cell--non-numeric">previously, celebrate, said, edited, also, announced, singing</td>
# </tr>
# <tr>
# <td>48</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://evonomics.com/keynes-was-really-a-conservative/">Keynes Was Really a Conservative</a></td>
# <td class="logit">4.793371200561523</td>
# <td class="top_words mdl-data-table__cell--non-numeric">whilst, inbox, economics, fiscal, deficits, obama, stimulus, ten, hundred</td>
# <td class="least_words mdl-data-table__cell--non-numeric">trump, added, wrote, while, said, deal, decried, told, also</td>
# </tr>
# <tr>
# <td>49</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://www.nationalaffairs.com//blog/detail/findings-a-daily-roundup/econ-gone-wild">Econ Gone Wild</a></td>
# <td class="logit">4.792867660522461</td>
# <td class="top_words mdl-data-table__cell--non-numeric">behavior, liquidity, behavioral, 2008, pages, 2009, 2007</td>
# <td class="least_words mdl-data-table__cell--non-numeric">explaining, related, previously, while, according, journal, crucially, escalate, due</td>
# </tr>
# <tr>
# <td>50</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://medium.com/@Chris_arnade/hell-this-is-reno-2f35d8875ba1?source=rss-9e28ee9292dc------2">Hell, this is Reno</a></td>
# <td class="logit">4.768763065338135</td>
# <td class="top_words mdl-data-table__cell--non-numeric">shit, talk, parking, drug, clients, hair, ten, fifteen</td>
# <td class="least_words mdl-data-table__cell--non-numeric">explaining, wednesday, shows, doesn, follows, fun, hurt, says, particularly, deal</td>
# </tr>
# <tr>
# <td>51</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://standpointmag.co.uk/issues/april-2020/robert-conquest-garland-for-a-propagandist/">Robert Conquest: Garland for a Propagandist</a></td>
# <td class="logit">4.763932228088379</td>
# <td class="top_words mdl-data-table__cell--non-numeric">books, overthrow, boldly, introduction, sir, insist, indeed, balance, ten, twentieth</td>
# <td class="least_words mdl-data-table__cell--non-numeric">2015, 2018, verse, elizabeth, said, edited, twist, told, also</td>
# </tr>
# <tr>
# <td>52</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="http://feedproxy.google.com/~r/craigmod/~3/TtqagfV5ByM/">[essays] The Long Road Back to 2000</a></td>
# <td class="logit">4.742609024047852</td>
# <td class="top_words mdl-data-table__cell--non-numeric">sitting, page, wikipedia, 2000, bubble, html, 2011, mail, ten, web</td>
# <td class="least_words mdl-data-table__cell--non-numeric">digital, pretty, released, fun, dovetails, releasing, stalwart, originally</td>
# </tr>
# <tr>
# <td>53</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://www.zocalopublicsquare.org/2020/05/15/where-i-go-rancho-penasquitos-san-diego-apartment-identity/chronicles/where-i-go/">Where I Go: Penasquitos Gardens</a></td>
# <td class="logit">4.733719825744629</td>
# <td class="top_words mdl-data-table__cell--non-numeric">2001, begged, talk, neighborhood, neighbor, cell, balance, hair, shotgun</td>
# <td class="least_words mdl-data-table__cell--non-numeric">holiday, bunch, shooting, said, families, aren, 90s, plans</td>
# </tr>
# <tr>
# <td>54</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://nplusonemag.com/online-only/online-only/the-psychiatrist/">The Psychiatrist</a></td>
# <td class="logit">4.73108434677124</td>
# <td class="top_words mdl-data-table__cell--non-numeric">cell, hair, israel, afternoon, jeans, twelve, ten, forty, twenty</td>
# <td class="least_words mdl-data-table__cell--non-numeric">read, stone, characters, shows, wrote, ruth, isn, while, pop, thrones</td>
# </tr>
# <tr>
# <td>55</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="http://copper-nickel.org/odd-numbers/">Odd Numbers</a></td>
# <td class="logit">4.722705841064453</td>
# <td class="top_words mdl-data-table__cell--non-numeric">neighborhood, thousand, tea, hair, drive, afternoon, ten, hundred, thirteen, twenty</td>
# <td class="least_words mdl-data-table__cell--non-numeric">explaining, vulture, read, hide, pretty, rudy, snap, while, watch</td>
# </tr>
# <tr>
# <td>56</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="http://feedproxy.google.com/~r/nybooks/~3/N-A4AqYm_PU/">Beyond Meaning: Joseph Brodsky’s Poetry of Exile</a></td>
# <td class="logit">4.7214035987854</td>
# <td class="top_words mdl-data-table__cell--non-numeric">typed, meters, whereas, seventies, giroux, farrar, straus, nineties, thirty, nineteenth</td>
# <td class="least_words mdl-data-table__cell--non-numeric">read, wrote, boris, beloved, previously, verse, while, artifacts, existential, solidarity</td>
# </tr>
# <tr>
# <td>57</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="http://feedproxy.google.com/~r/delanceyplace/rwVN/~3/5KtQl7Jtat0/view-archives.php">the leadership of deng xiaoping -- 4/28/20</a></td>
# <td class="logit">4.7209062576293945</td>
# <td class="top_words mdl-data-table__cell--non-numeric">northwest, harvard, chairman, eighty, 2011, pages, twelve, copyright, twenty</td>
# <td class="least_words mdl-data-table__cell--non-numeric">sen, ezra, while, dedicated, above, key, secretary, donated, attend</td>
# </tr>
# <tr>
# <td>58</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://nplusonemag.com/online-only/online-only/remainder/">Remainder</a></td>
# <td class="logit">4.717398166656494</td>
# <td class="top_words mdl-data-table__cell--non-numeric">gray, tea, hair, license, drive, brotherhood, ten, hundred, thirty</td>
# <td class="least_words mdl-data-table__cell--non-numeric">read, rolling, lightly, pretty, wrote, digs, snap, isn</td>
# </tr>
# <tr>
# <td>59</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://neo.life/2019/05/vanilla-memories/">Vanilla Memories</a></td>
# <td class="logit">4.7165703773498535</td>
# <td class="top_words mdl-data-table__cell--non-numeric">graph, drive, cofounder, afternoon, nervous, jeans, wondered, pages, neighboring</td>
# <td class="least_words mdl-data-table__cell--non-numeric">read, quarantine, pretty, boost, wrote, video, cdc, code, while</td>
# </tr>
# <tr>
# <td>60</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://www.berfrois.com/2020/05/emily-ogden-mind-games/">Emily Ogden: Mind Games</a></td>
# <td class="logit">4.715446949005127</td>
# <td class="top_words mdl-data-table__cell--non-numeric">remembers, faculty, talk, satisfaction, wikimedia, lapham, image, sixty, illustration</td>
# <td class="least_words mdl-data-table__cell--non-numeric">guardian, read, monday, wrote, 2018, museum, while, journal, released</td>
# </tr>
# <tr>
# <td>61</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="http://feedproxy.google.com/~r/Everywhereist/~3/A8e-cdZRan8/">I Write About Mice But Actually Anxiety.</a></td>
# <td class="logit">4.711244583129883</td>
# <td class="top_words mdl-data-table__cell--non-numeric">driveway, sitting, manner, dozen, onto, upper, articles, crap, neighborhood</td>
# <td class="least_words mdl-data-table__cell--non-numeric">twitter, while, doesn, released, carrie, literally, particularly, deal</td>
# </tr>
# <tr>
# <td>62</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="http://stormbear.com/the-bubba-sudsa/">The Bubba Sudsa</a></td>
# <td class="logit">4.710445404052734</td>
# <td class="top_words mdl-data-table__cell--non-numeric">insist, drunk, television, indeed, etc, credit</td>
# <td class="least_words mdl-data-table__cell--non-numeric">rating, smithsonian, read, changing, while, watch, according, debbie, bunch</td>
# </tr>
# <tr>
# <td>63</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="http://ben-kay.com/2020/05/advertising-by-gaslight/">Advertising by Gaslight</a></td>
# <td class="logit">4.708834648132324</td>
# <td class="top_words mdl-data-table__cell--non-numeric">behave, anymore, shit, crap, clients, hair, occasional</td>
# <td class="least_words mdl-data-table__cell--non-numeric">fun, initially, behaviour, week, seeing, also, paying, bit</td>
# </tr>
# <tr>
# <td>64</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://www.allendowney.com/blog/2020/04/13/bayesian-hypothesis-testing/">Bayesian hypothesis testing</a></td>
# <td class="logit">4.702567100524902</td>
# <td class="top_words mdl-data-table__cell--non-numeric">algorithms, hypothesis, probability, statistician, insist, summary, economics, statistical, euro</td>
# <td class="least_words mdl-data-table__cell--non-numeric">guardian, friday, statement, ahead, said, series, means, testing</td>
# </tr>
# <tr>
# <td>65</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://inference-review.com/index.php/article/a-hot-mess">A Hot Mess</a></td>
# <td class="logit">4.702016830444336</td>
# <td class="top_words mdl-data-table__cell--non-numeric">statistical, suppose, expectation, whereas, illustration</td>
# <td class="least_words mdl-data-table__cell--non-numeric">related, researchers, shows, according, released, argued, follows, hardware, due, proposal</td>
# </tr>
# <tr>
# <td>66</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="http://feedproxy.google.com/~r/TheRationalWalkFeed/~3/Qmm8tzy2IqE/">The Song Remains the Same</a></td>
# <td class="logit">4.697851657867432</td>
# <td class="top_words mdl-data-table__cell--non-numeric">2008, ten, interviews, hundred, fifty, cent, twenty, twentieth</td>
# <td class="least_words mdl-data-table__cell--non-numeric">read, tuesday, cnbc, wrote, percent, 2020, doesn, warned, thinks</td>
# </tr>
# <tr>
# <td>67</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://inference-review.com/index.php/article/kept-in-mind">Kept in Mind</a></td>
# <td class="logit">4.6826276779174805</td>
# <td class="top_words mdl-data-table__cell--non-numeric">whereas, deficits, concentrate, stimulus, twentieth</td>
# <td class="least_words mdl-data-table__cell--non-numeric">read, related, percent, previously, while, argued, follows, remarks</td>
# </tr>
# <tr>
# <td>68</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://nplusonemag.com/online-only/online-only/more-or-less/">More or Less</a></td>
# <td class="logit">4.681431293487549</td>
# <td class="top_words mdl-data-table__cell--non-numeric">desk, fuck, arranged, sitting, parking, gray, lobby, tea</td>
# <td class="least_words mdl-data-table__cell--non-numeric">isn, while, ahead, says, said, length, chair, week</td>
# </tr>
# <tr>
# <td>69</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://www.scottaaronson.com/blog/?p=4794">Four striking papers</a></td>
# <td class="logit">4.676440238952637</td>
# <td class="top_words mdl-data-table__cell--non-numeric">mentioned, graph, blog, 2009, twenty</td>
# <td class="least_words mdl-data-table__cell--non-numeric">related, wrote, previously, formally, recommended, favorite, matt, week, upshot</td>
# </tr>
# <tr>
# <td>70</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://medium.com/@tdietterich/reflections-on-innateness-in-machine-learning-4eebefa3e1af?source=rss-d5e56dd33516------2">Reflections on Innateness in Machine Learning</a></td>
# <td class="logit">4.675137042999268</td>
# <td class="top_words mdl-data-table__cell--non-numeric">wikipedia, languages, hence, exceed, obvious, behavior, org, web</td>
# <td class="least_words mdl-data-table__cell--non-numeric">https, researchers, while, according, adding, elizabeth, guide, typically, particularly</td>
# </tr>
# <tr>
# <td>71</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://philosophynow.org/issues/137/Bullshit_Jobs_by_David_Graeber">Bullshit Jobs by David Graeber</a></td>
# <td class="logit">4.667534828186035</td>
# <td class="top_words mdl-data-table__cell--non-numeric">multiplied, articles, 2005, 2008, image, pages, nineteenth, twenty</td>
# <td class="least_words mdl-data-table__cell--non-numeric">read, researchers, equality, 2020, 2018, essentially, while, follows, due</td>
# </tr>
# <tr>
# <td>72</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="http://feedproxy.google.com/~r/delanceyplace/rwVN/~3/YFyNtomxq28/view-archives.php">gutenberg, failed entrepreneur -- 4/22/20</a></td>
# <td class="logit">4.6641011238098145</td>
# <td class="top_words mdl-data-table__cell--non-numeric">owed, the, books, money, manner, license, pages, fifty, copyright</td>
# <td class="least_words mdl-data-table__cell--non-numeric">related, 2016, characters, percent, credited, incredible, donated, tackled, truly</td>
# </tr>
# <tr>
# <td>73</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://www.lemonde.fr/blog/piketty/2019/07/09/will-money-creation-save-us/">Will money creation save us?</a></td>
# <td class="logit">4.657807350158691</td>
# <td class="top_words mdl-data-table__cell--non-numeric">1935, system, ecb, 1000, furthermore, balance, whereas, euro, 2008, 2007</td>
# <td class="least_words mdl-data-table__cell--non-numeric">2018, above, clarified, particularly, deal, climate, hyper, during, entering</td>
# </tr>
# <tr>
# <td>74</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://nplusonemag.com/online-only/online-only/in-the-pit/">In the Pit</a></td>
# <td class="logit">4.624243259429932</td>
# <td class="top_words mdl-data-table__cell--non-numeric">nervous, jeans, translated, ten, fifteen, hundred, thirty, copyright, twenty</td>
# <td class="least_words mdl-data-table__cell--non-numeric">2016, previously, serve, while, according, earnings, meanwhile, literally, dip</td>
# </tr>
# <tr>
# <td>75</td>
# <td class="title mdl-data-table__cell--non-numeric"><a href="https://www.perell.com/blog/wall-of-heroes">Your Wall of Heroes</a></td>
# <td class="logit">4.613435745239258</td>
# <td class="top_words mdl-data-table__cell--non-numeric">room, friends, coaches, the, direction, television, explanations, marshall</td>
# <td class="least_words mdl-data-table__cell--non-numeric">read, lyrics, moments, adding, includes, favorite, aren, heroes</td>
# </tr>
